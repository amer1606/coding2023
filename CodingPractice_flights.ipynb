# %%
import pandas as pd
import numpy as np
flights = pd.read_csv('https://raw.githubusercontent.com/misrori/rdata/main/flights.csv')
airlines = pd.read_csv('https://raw.githubusercontent.com/misrori/rdata/main/airlines.csv')
planes = pd.read_csv('https://raw.githubusercontent.com/misrori/rdata/main/planes.csv')
weather = pd.read_csv('https://raw.githubusercontent.com/misrori/rdata/main/weather.csv')

# %%
flights.head(10)
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
# 5  2013      1    1     554.0             558       -4.0     740.0
# 6  2013      1    1     555.0             600       -5.0     913.0
# 7  2013      1    1     557.0             600       -3.0     709.0
# 8  2013      1    1     557.0             600       -3.0     838.0
# 9  2013      1    1     558.0             600       -2.0     753.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# ...

# %%
flights.origin
# Out:
# 0         EWR
# 1         LGA
# 2         JFK
# 3         JFK
# 4         LGA
#          ...
# 336771    JFK
# 336772    LGA
# 336773    LGA
# 336774    LGA
# 336775    LGA
# Name: origin, Length: 336776, dtype: object

# %%
flights.dep_delay
# Out:
# 0         2.0
# 1         4.0
# 2         2.0
# 3        -1.0
# 4        -6.0
#          ...
# 336771    NaN
# 336772    NaN
# 336773    NaN
# 336774    NaN
# 336775    NaN
# Name: dep_delay, Length: 336776, dtype: float64

# %%
JFK = flights[(flights.origin == "JFK") & (flights.dep_delay > 30)]

# %%
JFK.describe
# Out:
# <bound method NDFrame.describe of         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 135     2013      1    1     826.0             715       71.0    1136.0
# 151     2013      1    1     848.0            1835      853.0    1001.0
# 178     2013      1    1     909.0             810       59.0    1331.0
# 373     2013      1    1    1337.0            1220       77.0    1649.0
# 411     2013      1    1    1428.0            1329       59.0    1803.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336704  2013      9   30    2028.0            1910       78.0    2255.0
# 336708  2013      9   30    2032.0            1945       47.0    2115.0
# 336725  2013      9   30    2053.0            2015       38.0    2146.0
# 336757  2013      9   30    2159.0            1845      194.0    2344.0
# 336763  2013      9   30    2235.0            2001      154.0      59.0
#
# ...

# %%
longd = flights[(flights.distance > 1500) & (flights.arr_delay > 15)]

# %%
longd.describe
# Out:
# <bound method NDFrame.describe of         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 37      2013      1    1     628.0             630       -2.0    1016.0
# 69      2013      1    1     702.0             700        2.0    1058.0
# 102     2013      1    1     754.0             755       -1.0    1103.0
# 128     2013      1    1     821.0             820        1.0    1153.0
# 145     2013      1    1     833.0             835       -2.0    1134.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336674  2013      9   30    1956.0            1825       91.0    2208.0
# 336685  2013      9   30    2008.0            1935       33.0    2322.0
# 336704  2013      9   30    2028.0            1910       78.0    2255.0
# 336738  2013      9   30    2110.0            2055       15.0      51.0
# 336762  2013      9   30    2233.0            2113       80.0     112.0
#
# ...

# %%
flights.air_time
# Out:
# 0         227.0
# 1         227.0
# 2         160.0
# 3         183.0
# 4         116.0
#           ...
# 336771      NaN
# 336772      NaN
# 336773      NaN
# 336774      NaN
# 336775      NaN
# Name: air_time, Length: 336776, dtype: float64

# %%
amer = flights[(flights.carrier == "AA") & (flights.air_time < 120)]

# %%
amer.describe
# Out:
# <bound method NDFrame.describe of         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 108     2013      1    1     803.0             810       -7.0     903.0
# 326     2013      1    1    1237.0            1245       -8.0    1340.0
# 559     2013      1    1    1641.0            1650       -9.0    1746.0
# 752     2013      1    1    2013.0            2015       -2.0    2120.0
# 870     2013      1    2     603.0             600        3.0     733.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336550  2013      9   30    1757.0            1805       -8.0    1921.0
# 336600  2013      9   30    1849.0            1855       -6.0    2007.0
# 336645  2013      9   30    1928.0            1940      -12.0    2043.0
# 336700  2013      9   30    2022.0            2025       -3.0    2127.0
# 336709  2013      9   30    2032.0            2045      -13.0    2147.0
#
# ...

# %%
airlines
# Out:
#    carrier                         name
# 0       9E            Endeavor Air Inc.
# 1       AA       American Airlines Inc.
# 2       AS         Alaska Airlines Inc.
# 3       B6              JetBlue Airways
# 4       DL         Delta Air Lines Inc.
# 5       EV     ExpressJet Airlines Inc.
# 6       F9       Frontier Airlines Inc.
# 7       FL  AirTran Airways Corporation
# 8       HA       Hawaiian Airlines Inc.
# 9       MQ                    Envoy Air
# 10      OO        SkyWest Airlines Inc.
# 11      UA        United Air Lines Inc.
# 12      US              US Airways Inc.
# 13      VX               Virgin America
# 14      WN       Southwest Airlines Co.
# 15      YV           Mesa Airlines Inc.

# %%
fl_airlines = pd.merge(flights, airlines, on='carrier')

# %%
fl_airlines.head
# Out:
# <bound method NDFrame.head of         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     554.0             558       -4.0     740.0
# 3       2013      1    1     558.0             600       -2.0     924.0
# 4       2013      1    1     558.0             600       -2.0     923.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   19    1759.0            1805       -6.0    1946.0
# 336772  2013      9   20    1758.0            1805       -7.0    1929.0
# 336773  2013      9   22    1759.0            1805       -6.0    1945.0
# 336774  2013      9   23    1759.0            1805       -6.0    1935.0
# 336775  2013      9   24    1751.0            1805      -14.0    1937.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...
